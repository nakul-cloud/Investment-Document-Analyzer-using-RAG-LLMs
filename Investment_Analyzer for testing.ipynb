# %%
pip install langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in c:\users\nakul\anaconda3\lib\site-packages (1.0.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-text-splitters) (1.1.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.4.44)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\nakul\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\nakul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\nakul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\nakul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\nakul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\nakul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.23.0)
# Requirement already satisfied: anyio in c:\users\nakul\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (4.7.0)
# Requirement already satisfied: certifi in c:\users\nakul\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\nakul\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in c:\users\nakul\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\nakul\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nakul\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\nakul\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\nakul\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nakul\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nakul\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\nakul\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.3.0)

# %%
pip install langchain-community
# Out:
# Requirement already satisfied: langchain-community in c:\users\nakul\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-community) (1.1.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-community) (2.0.39)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-community) (0.4.44)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-community) (2.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\nakul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\nakul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\nakul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\nakul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\nakul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\nakul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\nakul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\nakul\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\nakul\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\nakul\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\nakul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\nakul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\nakul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\nakul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: anyio in c:\users\nakul\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.7.0)
# Requirement already satisfied: certifi in c:\users\nakul\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\nakul\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in c:\users\nakul\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\nakul\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nakul\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\nakul\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\nakul\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\nakul\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nakul\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nakul\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\nakul\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\nakul\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\nakul\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain pypdf chromadb sentence-transformers
# Out:
# Requirement already satisfied: langchain in c:\users\nakul\anaconda3\lib\site-packages (1.0.8)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pypdf in c:\users\nakul\anaconda3\lib\site-packages (6.3.0)
# Requirement already satisfied: chromadb in c:\users\nakul\anaconda3\lib\site-packages (1.3.5)
# Requirement already satisfied: sentence-transformers in c:\users\nakul\anaconda3\lib\site-packages (5.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.6 in c:\users\nakul\anaconda3\lib\site-packages (from langchain) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\nakul\anaconda3\lib\site-packages (from langchain) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\nakul\anaconda3\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (0.4.44)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\nakul\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\nakul\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.6->langchain) (2.1)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\nakul\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\nakul\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.4)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\nakul\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\nakul\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\nakul\anaconda3\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\nakul\anaconda3\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\nakul\anaconda3\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\nakul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\nakul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\nakul\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (0.23.0)
# Requirement already satisfied: anyio in c:\users\nakul\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.7.0)
# Requirement already satisfied: certifi in c:\users\nakul\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\nakul\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\nakul\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\nakul\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nakul\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\nakul\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\nakul\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: build>=1.0.3 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\nakul\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.38.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (2.1.3)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\nakul\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\nakul\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\nakul\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\nakul\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\nakul\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nakul\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nakul\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (2.3.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\nakul\anaconda3\lib\site-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\nakul\anaconda3\lib\site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: scikit-learn in c:\users\nakul\anaconda3\lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in c:\users\nakul\anaconda3\lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\nakul\anaconda3\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in c:\users\nakul\anaconda3\lib\site-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: filelock in c:\users\nakul\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.17.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\nakul\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\nakul\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\nakul\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: pyproject_hooks in c:\users\nakul\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\nakul\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\nakul\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\nakul\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\nakul\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\nakul\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.22.3)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\nakul\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\nakul\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\nakul\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\nakul\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\nakul\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nakul\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\nakul\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\nakul\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Requirement already satisfied: coloredlogs in c:\users\nakul\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\nakul\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in c:\users\nakul\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in c:\users\nakul\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\nakul\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\nakul\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\nakul\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\nakul\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\nakul\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\nakul\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.59b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\nakul\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\nakul\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\nakul\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\nakul\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\nakul\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\nakul\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nakul\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\nakul\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\nakul\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\nakul\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\nakul\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\nakul\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\nakul\anaconda3\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\nakul\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\nakul\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nakul\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\nakul\anaconda3\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\nakul\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\nakul\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)

# %%
pip install unstructured lxml
# Out:
# Requirement already satisfied: unstructured in c:\users\nakul\anaconda3\lib\site-packages (0.18.20)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: lxml in c:\users\nakul\anaconda3\lib\site-packages (5.3.0)
# Requirement already satisfied: charset-normalizer in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (3.3.2)
# Requirement already satisfied: filetype in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: nltk in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (2.32.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (4.12.3)
# Requirement already satisfied: emoji in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (2.15.0)
# Requirement already satisfied: dataclasses-json in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (2025.11.16)
# Requirement already satisfied: langdetect in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (2.1.3)
# Requirement already satisfied: rapidfuzz in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (3.14.3)
# Requirement already satisfied: backoff in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (4.15.0)
# Requirement already satisfied: unstructured-client in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (0.42.4)
# Requirement already satisfied: wrapt in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (1.17.0)
# Requirement already satisfied: tqdm in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (4.67.1)
# Requirement already satisfied: psutil in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (5.9.0)
# Requirement already satisfied: python-oxmsg in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: html5lib in c:\users\nakul\anaconda3\lib\site-packages (from unstructured) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nakul\anaconda3\lib\site-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\nakul\anaconda3\lib\site-packages (from dataclasses-json->unstructured) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\nakul\anaconda3\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\nakul\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\nakul\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: six>=1.9 in c:\users\nakul\anaconda3\lib\site-packages (from html5lib->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\nakul\anaconda3\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in c:\users\nakul\anaconda3\lib\site-packages (from nltk->unstructured) (8.1.8)
# Requirement already satisfied: joblib in c:\users\nakul\anaconda3\lib\site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\nakul\anaconda3\lib\site-packages (from nltk->unstructured) (2024.11.6)
# Requirement already satisfied: colorama in c:\users\nakul\anaconda3\lib\site-packages (from click->nltk->unstructured) (0.4.6)
# Requirement already satisfied: olefile in c:\users\nakul\anaconda3\lib\site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nakul\anaconda3\lib\site-packages (from requests->unstructured) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nakul\anaconda3\lib\site-packages (from requests->unstructured) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nakul\anaconda3\lib\site-packages (from requests->unstructured) (2025.11.12)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\users\nakul\anaconda3\lib\site-packages (from unstructured-client->unstructured) (25.1.0)
# Requirement already satisfied: cryptography>=3.1 in c:\users\nakul\anaconda3\lib\site-packages (from unstructured-client->unstructured) (44.0.1)
# Requirement already satisfied: httpcore>=1.0.9 in c:\users\nakul\anaconda3\lib\site-packages (from unstructured-client->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\nakul\anaconda3\lib\site-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: pydantic>=2.11.2 in c:\users\nakul\anaconda3\lib\site-packages (from unstructured-client->unstructured) (2.12.4)
# Requirement already satisfied: pypdf>=6.2.0 in c:\users\nakul\anaconda3\lib\site-packages (from unstructured-client->unstructured) (6.3.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\nakul\anaconda3\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\nakul\anaconda3\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\nakul\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.21)
# Requirement already satisfied: h11>=0.16 in c:\users\nakul\anaconda3\lib\site-packages (from httpcore>=1.0.9->unstructured-client->unstructured) (0.16.0)
# Requirement already satisfied: anyio in c:\users\nakul\anaconda3\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nakul\anaconda3\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\nakul\anaconda3\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\nakul\anaconda3\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.4.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\nakul\anaconda3\lib\site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.3.0)

# %%
pip install pypdf pathlib
# Out:
# Requirement already satisfied: pypdf in c:\users\nakul\anaconda3\lib\site-packages (6.3.0)
# Collecting pathlib
#   Downloading pathlib-1.0.1-py3-none-any.whl.metadata (5.1 kB)
# Downloading pathlib-1.0.1-py3-none-any.whl (14 kB)
# Installing collected packages: pathlib
# Successfully installed pathlib-1.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
 
import os
from dotenv import load_dotenv, find_dotenv
from pathlib import Path

# Load .env (keeps API keys out of source files)
filepath = r"C:\Users\Nakul\rag_api.env"
load_dotenv(find_dotenv(filepath)) 

# ========== Configuration (update these) ==========
PDF_FOLDER_PATH = r"D:\\Investment docs"          # folder with PDF prospectuses
CHROMA_PERSIST_DIR = "./chromadb_store"            # where Chroma will persist
CHROMA_COLLECTION = "financial_prospectuses"       # Chroma collection name
EMBEDDING_MODEL_NAME = "all-MiniLM-L6-v2"          # L6-mini
CHUNK_SIZE = 700
CHUNK_OVERLAP = 150
BATCH_EMBED = 64
TOP_K = 4

# LLM settings (Gemini via LangChain or local fallback)
GEMINI_MODEL = os.getenv("GEMINI_MODEL", "gemini-2.5-flash")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")       # ensure this exists for Gemini via langchain_google_genai
LOCAL_TGI_ENDPOINT = os.getenv("LOCAL_TGI_ENDPOINT", "http://localhost:8080/v1/models/gemin:predict")

# Create persistent directories if missing
Path(CHROMA_PERSIST_DIR).mkdir(parents=True, exist_ok=True)

# Quick print to confirm
print("Configuration summary:")
print(f"  PDF_FOLDER_PATH = {PDF_FOLDER_PATH}")
print(f"  CHROMA_PERSIST_DIR = {CHROMA_PERSIST_DIR}")
print(f"  EMBEDDING_MODEL_NAME = {EMBEDDING_MODEL_NAME}")
print(f"  GEMINI_MODEL = {GEMINI_MODEL}")
print(f"  GOOGLE_API_KEY set? {'YES' if bool(GOOGLE_API_KEY) else 'NO'}")
if GOOGLE_API_KEY:
    print("API key loaded successfully:",GOOGLE_API_KEY)
else:
    print("API key not loaded.")

# %%
import os
from pathlib import Path
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma

# --- Configuration ---
# ⚠️ UPDATE THIS PATH with the fixed, accessible folder containing your PDFs
PDF_FOLDER_PATH = r'D:\Investment docs'
# Define where the vector database will be stored locally
CHROMA_PERSIST_DIR = './chroma_db'
# Use a high-quality, general-purpose Sentence Transformer model
EMBEDDING_MODEL_NAME = 'all-MiniLM-L6-v2' 

# --- A. Document Loading & OCR (Uses PyPDFLoader for text extraction) ---
print(f"--- Step A: Loading documents from {PDF_FOLDER_PATH} ---")
all_documents = []

# Use LangChain's directory loader to handle all PDFs in the folder
try:
    for file_path in Path(PDF_FOLDER_PATH).glob("*.pdf"):
        # PyPDFLoader extracts text and preserves basic metadata (source, page)
        loader = PyPDFLoader(str(file_path))
        documents = loader.load()
        all_documents.extend(documents)
    
    if not all_documents:
        print("Error: No PDF files found or could be loaded. Check PDF_FOLDER_PATH.")
        exit()

except Exception as e:
    print(f"An error occurred during file loading: {e}")
    exit()

print(f"✅ Loaded {len(all_documents)} pages across all documents.")
# Out:
# --- Step A: Loading documents from D:\Investment docs ---
# ✅ Loaded 188 pages across all documents.

# %%
# Assuming 'all_documents' from Step A is loaded

# --- B. Intelligent Chunking ---
# NOTE: The import below is corrected to 'langchain_text_splitters'
from langchain_text_splitters import RecursiveCharacterTextSplitter 

print("--- Step B: Performing Intelligent Chunking ---")
text_splitter = RecursiveCharacterTextSplitter(
    # Chunk size: ~700 characters is a good starting point for LLM context
    chunk_size=700,
    # Overlap: Ensures sentences aren't cut mid-context
    chunk_overlap=150,
    length_function=len 
)

# Split the loaded pages into smaller chunks
chunks = text_splitter.split_documents(all_documents)
print(f"✅ Split into {len(chunks)} chunks for indexing.")

 


# ---------- 1) Recursive chunking (document-level) ----------
print("Step 1: Chunking with RecursiveCharacterTextSplitter")
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=CHUNK_SIZE,
    chunk_overlap=CHUNK_OVERLAP,
    length_function=len
)

# `split_documents` expects a list of LangChain Document objects
chunks = text_splitter.split_documents(all_documents)  # <- uses your loaded pages/documents
print(f"Produced {len(chunks)} chunks from {len(all_documents)} input documents/pages.")
# Out:
# --- Step B: Performing Intelligent Chunking ---
# ✅ Split into 1427 chunks for indexing.
# Step 1: Chunking with RecursiveCharacterTextSplitter
# Produced 1427 chunks from 188 input documents/pages.

# %%
from sentence_transformers import SentenceTransformer
import chromadb
from chromadb.config import Settings
import math
import numpy as np
from tqdm.auto import tqdm
import time
import uuid

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma

 
# --- C. Text Embedding ---
print(f"--- Step C: Initializing Embedding Model ({EMBEDDING_MODEL_NAME}) ---")

# HuggingFaceEmbeddings loads the specified model ('all-MiniLM-L6-v2') 
# from the Hugging Face Hub (or local cache) and provides the function 
# to convert text chunks into numerical vectors.
embeddings = HuggingFaceEmbeddings(model_name=EMBEDDING_MODEL_NAME)

print("✅ Embedding model loaded successfully.")

# --- D. Vector Storage ---
print(f"--- Step D: Creating and Persisting Vector Store (ChromaDB) ---")

 
vector_store = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory=CHROMA_PERSIST_DIR,
    collection_name="financial_prospectuses"
)

# Save the index to disk for later retrieval
vector_store.persist()
print(f"✅ ChromaDB index created and saved to {CHROMA_PERSIST_DIR}")
print("\n--- INGESTION COMPLETE ---")
# Out:
# --- Step C: Initializing Embedding Model (all-MiniLM-L6-v2) ---
# C:\Users\Nakul\AppData\Local\Temp\ipykernel_15624\4212220755.py:15: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name=EMBEDDING_MODEL_NAME)
# ✅ Embedding model loaded successfully.
# --- Step D: Creating and Persisting Vector Store (ChromaDB) ---
# ✅ ChromaDB index created and saved to ./chroma_db
#
# --- INGESTION COMPLETE ---
# C:\Users\Nakul\AppData\Local\Temp\ipykernel_15624\4212220755.py:33: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   vector_store.persist()

# %%
import os
# Components for loading the index
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

# Core LangChain components for the RAG chain
from langchain_core.runnables import RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate


# --- Configuration (Must match the Indexing script) ---
CHROMA_PERSIST_DIR = './chroma_db'
EMBEDDING_MODEL_NAME = 'all-MiniLM-L6-v2' 
# LLM_MODEL will be defined in the next section

def initialize_retriever():
    """Loads the vector store and creates a retriever object."""
    print("--- Step E.1: Loading Retriever ---")
    
    # 1. Load the same embedding model used for indexing
    embeddings = HuggingFaceEmbeddings(model_name=EMBEDDING_MODEL_NAME)

    # 2. Load the persisted vector store (ChromaDB)
    vector_store = Chroma(
        persist_directory=CHROMA_PERSIST_DIR, 
        embedding_function=embeddings,
        collection_name="financial_prospectuses"
    )

    # 3. Convert the vector store into a Retriever
    # search_kwargs={"k": 5} tells it to fetch the top 5 most relevant documents
    retriever = vector_store.as_retriever(search_kwargs={"k": 5})
    print("✅ Retriever initialized from ChromaDB index.")
    
    return retriever

# Run the initialization
retriever = initialize_retriever()
# Out:
# --- Step E.1: Loading Retriever ---
# ✅ Retriever initialized from ChromaDB index.
# C:\Users\Nakul\AppData\Local\Temp\ipykernel_15624\2206666511.py:25: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   vector_store = Chroma(

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

print("--- Step F: Building RAG Prompt, Formatter, and Chain ---")

# --- 1. RAG Prompt Template ---
rag_template = """
You are a precise and reliable financial analyst.
Answer the user's question **ONLY** using the information provided in the CONTEXT.
If the answer is not present in the context, reply:
"I don't know (not in document)."

Follow these rules:
- Be concise and factual (4–6 sentences).
- NEVER invent numbers or facts.
- At the end, provide a PROVENANCE section listing:
  Source (file), Page number, Chunk ID.

QUESTION:
{question}

CONTEXT:
{context}

ANSWER:
"""

rag_prompt = ChatPromptTemplate.from_template(rag_template)
print("✓ RAG prompt template created.")
# Out:
# --- Step F: Building RAG Prompt, Formatter, and Chain ---
# ✓ RAG prompt template created.

# %%
# Context formatting helper (Documents → clean text block) ---

def format_docs(docs):
    """
    Converts retriever results (list of Document objects)
    into a human-readable context block with provenance.
    """
    formatted = []
    for i, d in enumerate(docs):
        md = d.metadata
        src = md.get("source", "unknown_source")
        page = md.get("page_num", md.get("page", "?"))
        chunk_id = md.get("chunk_id", f"chunk_{i}")

        header = f"[Chunk {i+1}] Source: {src} | Page: {page} | ChunkID: {chunk_id}"
        formatted.append(f"{header}\n{d.page_content}")

    return "\n\n---\n\n".join(formatted)

format_docs_runnable = RunnableLambda(format_docs)
print("✓ Document formatter created.")
# Out:
# ✓ Document formatter created.

# %%
# Function Definition (Needs 3 arguments)
def build_rag_chain(llm_object, retriever_object, prompt_object): # <-- ADDED prompt_object
    """Assembles the final RAG chain (Retrieval + Generation)."""
    rag_chain = (
        {
            # Note: Assuming 'format_docs_runnable' is correctly defined elsewhere
            "context": retriever_object | format_docs_runnable,  
            "question": RunnablePassthrough()                      
        }
        | prompt_object # <--- Used here
        | llm_object    
        | StrOutputParser()
    )
    print("✓ RAG chain assembled successfully.")
    return rag_chain

# %%
# Simple LLM initialization (Gemini only)

from langchain_google_genai import ChatGoogleGenerativeAI

# Make sure GOOGLE_API_KEY is already exported or set via dotenv
GEMINI_MODEL = "gemini-2.5-flash"

print("Initializing Gemini LLM...")

llm = ChatGoogleGenerativeAI(
    model=GEMINI_MODEL,
    temperature=0.1   # stable, factual answers
)

print(f"✓ Gemini model loaded: {GEMINI_MODEL}")
# Out:
# Initializing Gemini LLM...
# ✓ Gemini model loaded: gemini-2.5-flash

# %%
final_rag_chain = build_rag_chain(llm, retriever, rag_prompt)
# Out:
# ✓ RAG chain assembled successfully.

# %%
user_question = "What is the investment objective?"
print(f"\n--- Running RAG Query for: {user_question} ---")

try:
    # 2. INVOKE the method on the created chain object
    answer = final_rag_chain.invoke(user_question)
    
    # Run this print statement cleanly
    print(f"\n--- Final Answer ---\n{answer}") 
    
except Exception as e:
    print(f"\nERROR running the chain: {e}")
# Out:
# --- Running RAG Query for: What is the investment objective? ---
#
# --- Final Answer ---
# The investment objective of the scheme is to seek to generate regular returns and growth of capital. This is achieved by investing in a diversified portfolio of debt and money market securities. These securities must mature on or before the term of the Scheme. It is important to note that the Scheme does not guarantee or indicate any returns, and there is no assurance that its objectives will be achieved.
#
# PROVENANCE:
# Source: D:\Investment docs\KIM - ABSL Interval Income Fund-QP-S I - 311023.pdf, Page: 2, ChunkID: chunk_0

# %%
# --- 4. Assemble the RAG Chain using LCEL ---

def assemble_rag_chain(llm_object, retriever_object, prompt_object):
    """Assembles the final RAG chain (Retrieval + Generation)."""
    rag_chain = (
        # 1. Context: Use the retriever to fetch docs and format them
        {"context": retriever_object | RunnableLambda(format_docs), 
         # 2. Question: Pass the original user question through
         "question": RunnablePassthrough()}
        | prompt_object # 3. Inject context and question into the prompt
        | llm_object    # 4. Send the prompt to the LLM
        | StrOutputParser() # 5. Parse the output as a simple string
    )
    print("✅ RAG Chain pipeline assembled.")
    return rag_chain

# Assemble the chain using the components initialized above
final_rag_chain = assemble_rag_chain(llm, retriever, rag_prompt)


# --- 5. Run the Query ---

user_question = "What is the investment objective for the Hartford Small Cap Value Fund and what is the latest total expense ratio?"

print(f"\n--- Running RAG Query ---")
print(f"User Question: {user_question}")

try:
    # Invoke the chain with the user's question
    response = final_rag_chain.invoke(user_question)
    
    print(f"\n--- Final Answer ---\n{response}")
    
except Exception as e:
    print(f"\nERROR: Could not run the RAG chain. Ensure your LLM API key is correctly configured. Error details: {e}")
# Out:
# ✅ RAG Chain pipeline assembled.
#
# --- Running RAG Query ---
# User Question: What is the investment objective for the Hartford Small Cap Value Fund and what is the latest total expense ratio?
#
# --- Final Answer ---
# The information regarding the investment objective for the Hartford Small Cap Value Fund and its latest total expense ratio is not available in the provided documents.
